# %%
import pandas as pd
from pandasai import SmartDataframe
from pandasai.llm import OpenAI

llm = OpenAI(api_token="HIER_DEN_OPENAI_API_KEY_EINFUEGEN")
df = pd.read_csv("https://raw.githubusercontent.com/a-wendler/musik-python-seminar1/main/mvdb_1000.csv")
smart_df = SmartDataframe(df, config={"llm": llm})

# %%
smart_df.chat("wieviele datensätze enthält das dataframe?")
# Out:
# 1000

# %%
smart_df.chat("die tabelle enthält daten zu notendrucken. die spalte published_subitems.prints.date_of_action enthält das veröffentlichungsdatum des drucks. die spalte works.composers.name enthält den name des komponisten. die spalte published_subitems.prints.quantity enthält die auflagenhöhe des drucks. plotte ein diagram, das die jährliche auflagenhöhe aller drucke des komponisten Mozart, Wolfgang Amadeus zwischen 1830 und 1930 darstellt.")
# Out:
# <string>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# '/workspaces/musik-python-1/exports/charts/temp_chart.png'

# %%
smart_df.chat("von welchem komponist wurden 1870 die meisten drucke produziert. die anzahl der produzierten drucke steht in spalte published_subitems.prints.quantity")
# Out:
# 'The composer with the most prints produced in 1870 is Franz, Robert.'

# %%
pd.read_excel()
