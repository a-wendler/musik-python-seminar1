# %%
import requests

# %%
url = "https://musikverlage.slub-dresden.de/api/search?q=Requiem AND Brahms"

# http-responste speichern
response = requests.get(url)

# json-daten aus der http_responst in eine python-variable überführen
daten = response.json()

# %%
daten["hits"]["hits"]
# Out:
# [{'_index': 'published_item',
#   '_id': 'RB_00029',
#   '_score': 103.1824,
#   '_source': {'uid': 2817,
#    'title': 'op. 1. Requiem für vierstimmigen Chor & Solostimmen mit obligater Orgelbegleitung.',
#    'type': 'work',
#    'mvdb_id': 'RB_00029',
#    'piano_combination': '',
#    'final': 2,
#    'editors': None,
#    'composers': None,
#    'works': [{'uid': 3184,
#      'generic_title': 'Requiem',
#      'individual_title': '',
#      'gnd_id': '1205775226',
#      'title_instrument': '',
#      'opus_number': '1',
#      'index_number': '',
#      'title_number': '',
#      'firstcomposer': 1834,
#      'main_instrumentation': 53282,
#      'publishers': 'RB',
#      'full_title': 'Requiem',
#      'date_of_production': '1857-01-01',
#      'tonality': '',
#      'gnd_instruments': [{'uid': 4, 'name': 'Orgel', 'gnd_id': '4043844-2'},
#       {'uid': 3584, 'name': 'Chor', 'gnd_id': '4010045-5'},
#       {'uid': 4610, 'name': 'Sopran', 'gnd_id': '4392005-6'},
# ...
