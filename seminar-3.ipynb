# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/a-wendler/musik-python-seminar1/main/mvdb_1000.csv")

# %%
df
# Out:
#        uid                                              title  \
# 0     1067                                  Matthäus-Passion.
# 1     3473          op. 120: Canticum Cantic. (Das Hohe Lied)
# 2     1078                                Orgelcompositionen.
# 3    13891                   Album. Bd. I. Volksausgabe. Tief
# 4    11218                   Concert No. 1. f. Kl. & Violine.
# ..     ...                                                ...
# 995    380                             op. 144. Neujahrslied.
# 996  13927                                         Album tief
# 997  12767                                   Strauss-Album 2h
# 998   2687  opus 33 Heft 1 à 5 f. tiefe Stimme Romanzen a....
# 999   1078                                Orgelcompositionen.
#
#                 type    mvdb_id piano_combination  final  editors.uid  \
# 0               work   PE_00023               NaN      2          NaN
# 1         adaptation   RB_02357               NaN      1          NaN
# ...

# %%
df["jahr"] = df["published_subitems.prints.date_of_action"].str[:4]

# %%
df["jahr"]
# Out:
# 0      1922
# 1      1906
# 2      1878
# 3      1889
# 4      1885
#        ...
# 995    1880
# 996    1887
# 997    1881
# 998    1897
# 999    1884
# Name: jahr, Length: 1000, dtype: object

# %%
df["published_subitems.prints.published_subitem"].value_counts()
# Out:
# 21501.0    17
# 21507.0    16
# 21508.0    13
# 21411.0    12
# 21510.0    12
#            ..
# 24024.0     1
# 29056.0     1
# 28927.0     1
# 30681.0     1
# 1561.0      1
# Name: published_subitems.prints.published_subitem, Length: 612, dtype: int64

# %%
1 < 2
# Out:
# True

# %%
df.loc[df["works.composers.name"] == "Mozart, Wolfgang Amadeus"].pivot_table(values="published_subitems.prints.quantity", columns="jahr", aggfunc="sum").transpose().plot()
# Out:
# <Axes: xlabel='jahr'>

# %%
df["works.composers.name"].value_counts()
# Out:
# works.composers.name
# Bach, Johann Sebastian      108
# Schubert, Franz             102
# Schick, Otto                102
# Beethoven, Ludwig van      75
# Mozart, Wolfgang Amadeus     49
#                            ...
# Wagner, Richard               1
# Panofka, Heinrich             1
# Boccherini, Luigi             1
# Egghard, Jules                1
# Lange, Samuel de            1
# Name: count, Length: 144, dtype: int64

# %%
filter = df["works.composers.name"] == "Mozart, Wolfgang Amadeus"

df.loc[filter]["published_subitems.prints.quantity"].sum()
# Out:
# 60675.0

# %%
df.loc[df["works.composers.name"] == "Bach, Johann Sebastian"]["jahr"].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='jahr'>

# %%
df["jahr"] = df["published_subitems.prints.date_of_action"].str[:4]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 85 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   uid                                               1000 non-null   int64
#  1   title                                             986 non-null    object
#  2   type                                              997 non-null    object
#  3   mvdb_id                                           1000 non-null   object
#  4   piano_combination                                 141 non-null    object
#  5   final                                             1000 non-null   int64
#  6   editors.uid                                       41 non-null     float64
#  7   editors.name                                      41 non-null     object
#  8   editors.gnd_id                                    41 non-null     object
# ...
